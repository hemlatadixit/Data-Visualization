# %%
import pandas as pd
df=pd.read_csv("Advertising.csv",index_col=0)
df
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
import seaborn as sns
sns.relplot(x="TV",y="sales",data=data);

# %%
import seaborn as sns
sns.relplot(x="newspaper",y="sales",data=data);

# %%
sns.relplot(x="radio",y="sales",data=data);

# %%
sns.pairplot(df);

# %% [markdown]
# ### categorical data ploting

# %% [markdown]
# ### categorical scatter plot

# %% [markdown]
# #### 1: striplot
# #### 2: swarmplot

# %% [markdown]
# ### categorical distribution plots

# %% [markdown]
# #### 1:boxplot
# #### 2:voilinplot

# %% [markdown]
# ### categorical estimate plot

# %% [markdown]
# #### 1:barplot
# #### 2:countplot

# %% [markdown]
# ### categorical categorical plots

# %% [markdown]
# ### heatplot

# %% [markdown]
# ### count plot is used for univariate analysis
# it is used for categorical adata same as value_counts

# %%
df=sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## how many males and females visited in tha restrauant

# %%
sns.countplot(x="sex",data=df);

# %% [markdown]
# ### catplot(): when one is categorical and another one is numeric data

# %%
sns.countplot(x="smoker",data=df);

# %% [markdown]
# at what time costumer visited most
# or peak time

# %%
sns.countplot(x="time",data=df);

# %%
sns.countplot(x="time",data=df,order=["Dinner","Lunch"]);

# %%
sns.countplot(x="day",data=df);  ## find out tha peak day

# %%
### on which day female and males vixsited more
sns.countplot(x="day",hue="sex",data=df);

# %%
### how many smoker and non smoker males and femlaes 
sns.countplot(x="sex",hue="smoker",data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## barplot : used for viberiate analysis
# when omne column is catogorical and numerical
# (is use to compare categorical)

# %% [markdown]
# ##  find out who paid maximum bill

# %%
sns.catplot(x="sex",y="total_bill",data=df,kind="bar",estimator=sum);

# %%
sns.catplot(x="sex",y="total_bill",data=df,kind="bar")

# %% [markdown]
# ## on which day tips given maximum by costumer.

# %%
sns.barplot(x="day",y="tip",data=df);

# %% [markdown]
# ### who paid highest  tip  based on each day

# %%
sns.barplot(x="day",y="tip",hue="sex",data=df);

# %%
## i want who visist more smoker and non smoker
sns.countplot(x="time",hue="smoker",data=df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
#find oit th atha who paid mxm bill smoker and non smoker
sns.countplot(x="sex",hue="smoker",data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ### Swarmplot

# %%
sns.catplot(x="day",y="total_bill",data=df,kind="swarm");

# %%
sns.catplot(x="day",y="total_bill",data=df,jitter=False);

# %%
sns.catplot(x="time",y="total_bill",data=df,kind="swarm");

# %%
sns.boxplot(df["tip"]);
# Out:
# C:\Users\ad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df["total_bill"]);
# Out:
# C:\Users\ad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x="day",y="tip",data=df,kind="box",dodge=True)

# %%
## violet plot is advantages=(showing statatics and distribution)
sns.violinplot(df["total_bill"]);
# Out:
# C:\Users\ad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x="day",y="total_bill",kind="violin",data=df)

# %% [markdown]
# ## distplot ;; used to do univariate analysis on a continuous data.

# %% [markdown]
# ### its contain three thing
# ## 1: histogram
# ## 2: kde(kernal density)/pdf
# ## 3: rugplot(optional)

# %% [markdown]
# ## displot() : this plot gives distribution  in  form kde(kernal density) and plus hoistrogram

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df["age"].isnull().sum()
# Out:
# 177

# %%
df["age"].fillna(df["age"].mean(),inplace=True)

# %%
df["age"].isnull().sum()
# Out:
# 0

# %%
sns.distplot(df["age"]);
# Out:
# C:\Users\ad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df["age"],kde=False);
# Out:
# C:\Users\ad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df["age"],hist=False);
# Out:
# C:\Users\ad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
import numpy as np
np.histogram(df["age"],bins=10)
# Out:
# (array([ 54,  46, 177, 346, 118,  70,  45,  24,   9,   2], dtype=int64),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]))

# %%
import matplotlib.pyplot as plt
plt.plot(bins[1:],pdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(bins[1:],pdf)
#
# NameError: name 'bins' is not defined

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_setosa=iris[iris["species"]=="setosa"]
iris_versicolor=iris[iris["species"]=="versicolor"]
iris_virginica=iris[iris["species"]=="virginica"]

# %%
iris_setosa
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
iris_versicolor
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
iris_virginica
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
sns.distplot(iris_setosa["petal_length"],label="setosa")
sns.distplot(iris_versicolor["petal_length"],label="versicolor")
sns.distplot(iris_virginica["petal_length"],label="virginica")
plt.legend();
# Out:
# C:\Users\ad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.distplot(iris_setosa["petal_width"],label="setosa")
sns.distplot(iris_versicolor["petal_width"],label="versicolor")
sns.distplot(iris_virginica["petal_width"],label="virginica")
plt.legend();
# Out:
# C:\Users\ad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
